# %% [markdown]
# <a href="https://colab.research.google.com/github/Alemisa/Machine-Learning_Practical-Sessions/blob/main/Lab%2002_Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lab02**:Simple Linear Regression

# %% [markdown]
# Problem 1: predict the salary of the employees based on years of experience

# %%
#Step 1: Import Requered labraries
import pandas as pd
import numpy as np

# %%
#Step 2: Import dataset
dataset = pd.read_csv("emp_data.csv")

# %%
#Step 3: Display all dataset
dataset
# Out:
#     experience  Salary
# 0          1.1   39343
# 1          1.3   46205
# 2          1.5   37731
# 3          2.0   43525
# 4          2.2   39891
# 5          2.9   56642
# 6          3.0   60150
# 7          3.2   54445
# 8          3.2   64445
# 9          3.7   57189
# 10         3.9   63218
# 11         4.0   55789
# 12         4.0   56957
# 13         4.1   57081
# 14         4.5   61111
# 15         4.9   67938
# 16         5.1   66029
# 17         5.3   83088
# 18         5.9   81363
# 19         6.0   93940
# 20         6.8   91738
# 21         7.1   98273
# 22         7.9  101303
# 23         8.2  113812
# 24         8.7  109431
# 25         9.0  105582
# 26         9.5  116969
# 27         9.6  112635
# 28        10.3  122391
# 29        10.5  121872

# %%
#Display the head of dataset
dataset.head()
# Out:
#    experience  Salary
# 0         1.1   39343
# 1         1.3   46205
# 2         1.5   37731
# 3         2.0   43525
# 4         2.2   39891

# %%
#Display the tail of dataset
dataset.tail()
# Out:
#     experience  Salary
# 25         9.0  105582
# 26         9.5  116969
# 27         9.6  112635
# 28        10.3  122391
# 29        10.5  121872

# %%
#Step 4: Checking the shape of a dataset
dataset.shape
# Out:
# (30, 2)

# %%
#Checking Dataset Information
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   experience  30 non-null     float64
#  1   Salary      30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
#Step 6:  Checking Dataset Information
dataset.isnull().count()
# Out:
# experience    30
# Salary        30
# dtype: int64

# %% [markdown]
# ====Model Building===

# %%
#step1:Splitting of the dataset into independent and dependent variables
#Now let first define X and Y values
x=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values

# %%
#Now X=independent variable
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
#Now Y=Dependent variable
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55789,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101303, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872])

# %%
#Step 2: Plotting Scatter plot to check the relationship between the independent
#variable and the dependent variable
#import libraries for scatter plot
import matplotlib.pyplot as plt
plt.scatter(x,y,color="red")

# %% [markdown]
# Note: We can observe that the independent and dependent variable is linearly related to each other

# %%
#Step 3: Splitting the dataset for the training set and testing set
#Now let's split the dataset into training and testing ( 70,30)
#first, we need to input the library for this process
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=0)

# %%
#Now let's see the value together
x_train,x_test,y_train,y_test
# Out:
# (array([[ 7.9],
#         [ 2.9],
#         [ 5.1],
#         [ 3.2],
#         [ 4.5],
#         [ 8.2],
#         [ 6.8],
#         [ 1.3],
#         [10.5],
#         [ 3. ],
#         [ 2.2],
#         [ 5.9],
#         [ 6. ],
#         [ 3.7],
#         [ 3.2],
#         [ 9. ],
#         [ 2. ],
#         [ 1.1],
#         [ 7.1],
#         [ 4.9],
#         [ 4. ]]),
#  array([[ 1.5],
#         [10.3],
#         [ 4.1],
#         [ 3.9],
#         [ 9.5],
#         [ 8.7],
#         [ 9.6],
#         [ 4. ],
#         [ 5.3]]),
#  array([101303,  56642,  66029,  64445,  61111, 113812,  91738,  46205,
#         121872,  60150,  39891,  81363,  93940,  57189,  54445, 105582,
#          43525,  39343,  98273,  67938,  56957]),
#  array([ 37731, 122391,  57081,  63218, 116969, 109431, 112635,  55789,
#          83088]))

# %% [markdown]
# ===Working with regression===

# %%
#first we need to input the library for regression
from sklearn.linear_model import LinearRegression
#let make a function for regression as reg
reg=LinearRegression()
#lets fit the model with our split dataset.
#first we try for train and then for test and compare.
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ====Predicting results===

# %%
#Now let's predict,
y_predict=reg.predict(x_test)
y_predict
# Out:
# array([ 40817.75673712, 123188.24906078,  65154.49310548,  63282.43646176,
#        115700.0224859 , 108211.79591102, 116636.05080776,  64218.46478362,
#         76386.83296779])

# %%
#now x_test
x_test
# Out:
# array([[ 1.5],
#        [10.3],
#        [ 4.1],
#        [ 3.9],
#        [ 9.5],
#        [ 8.7],
#        [ 9.6],
#        [ 4. ],
#        [ 5.3]])

# %%
x_train
# Out:
# array([[ 7.9],
#        [ 2.9],
#        [ 5.1],
#        [ 3.2],
#        [ 4.5],
#        [ 8.2],
#        [ 6.8],
#        [ 1.3],
#        [10.5],
#        [ 3. ],
#        [ 2.2],
#        [ 5.9],
#        [ 6. ],
#        [ 3.7],
#        [ 3.2],
#        [ 9. ],
#        [ 2. ],
#        [ 1.1],
#        [ 7.1],
#        [ 4.9],
#        [ 4. ]])

# %%
y_test
# Out:
# array([ 37731, 122391,  57081,  63218, 116969, 109431, 112635,  55789,
#         83088])

# %%
y_train
# Out:
# array([101303,  56642,  66029,  64445,  61111, 113812,  91738,  46205,
#        121872,  60150,  39891,  81363,  93940,  57189,  54445, 105582,
#         43525,  39343,  98273,  67938,  56957])

# %% [markdown]
# ===Calculating Error/ Residue==

# %%
#Calculating Error/ Residue
residue = y_predict - y_test    # residue or error between actual and predicted salary
residue
# Out:
# array([ 3086.75673712,   797.24906078,  8073.49310548,    64.43646176,
#        -1268.9775141 , -1219.20408898,  4001.05080776,  8429.46478362,
#        -6701.16703221])

# %% [markdown]
# ====Visualization ====

# %%
#Now lets Visualize the training set results. i.e display on  graph
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,reg.predict(x_train),color='blue')
plt.title("Training Set: Salary vs Experinces",size=12)
plt.xlabel("Year of Employee",size=10)
plt.ylabel("Salaries of Employee",size=10)
plt.show()

# %%
# Now lets Visualize the test set results. i.e display on  graph now lets predict for test
#copy the same code and change it
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,reg.predict(x_test),color='blue')
plt.title("Linear Regression: Salary vs Experinces",size=12)
plt.xlabel("Year of Employee",size=10)
plt.ylabel("Saleries of Employee",size=10)
plt.show()

# %% [markdown]
# ===Calculating Intercept and Coefficient===

# %%
#calcualting coefficient
print(reg.coef_)
# Out:
# [9360.2832186]

# %%
#calcualting intercept
print(reg.intercept_)
# Out:
# 26777.331909226144

# %% [markdown]
# ===Model Evaluation===

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_predict))
r2 = r2_score(y_test,y_predict) #built-in function r2_score() indicates R-squared value
print("RMSE =", rmse)
print("R2 Score=",r2)
# Out:
# RMSE = 4835.23873294085
# R2 Score= 0.9740897704385739

# %% [markdown]
#                  ====Note===

# %% [markdown]
# •In this lab, We saw how we can build a machine learning model ie., Regression model and
# predict the salary of the employees based on years of experience.
# •Here, We build a regression model and check the model RMSE which is equal to 4585.415720467589.
# •We also checked for R2 score of our model which is equal to 0.9749154407708353
# or 97%. Which is a very good R2 score.
